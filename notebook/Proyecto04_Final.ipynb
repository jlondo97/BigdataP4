# %%
from pyspark.ml.feature import Tokenizer
from pyspark.ml.feature import StopWordsRemover
from pyspark.sql.functions import *

# %% [markdown]
# # Ingesta de datos de hdsf en dataframes

# %%
csv = '/user/jlondo97/datasets/articles1.csv'
df1 = spark.read.csv(csv,inferSchema=True,header=True)
csv = '/user/jlondo97/datasets/articles2.csv'
df2 = spark.read.csv(csv,inferSchema=True,header=True)
csv = '/user/jlondo97/datasets/articles3.csv'
df3 = spark.read.csv(csv,inferSchema=True,header=True)

# %%
join_1_df_2 = df1.join(df2, on=['_c0', 'id', 'title', 'publication', 'author', 'date', 'year', 'month', 'url', 'content'], how='left_outer')
full_df = join_1_df_2.join(df3, on=['_c0', 'id', 'title', 'publication', 'author', 'date', 'year', 'month', 'url', 'content'], how='left_outer')
full_df = full_df.limit(400)
full_df.show()
# Out:
# +-----+-----+--------------------+--------------+--------------------+----------+------+-----+----+--------------------+
# |  _c0|   id|               title|   publication|              author|      date|  year|month| url|             content|
# +-----+-----+--------------------+--------------+--------------------+----------+------+-----+----+--------------------+
# |10092|28828|Watch: Amazon Bos...|     Breitbart|         Nate Church|2017-03-21|2017.0|  3.0|null|At the MARS 2017 ...|
# |10101|28837|Patriots Owner Ro...|     Breitbart|         Trent Baker|2017-02-03|2017.0|  2.0|null|”I remember who t...|
# |10236|28972|Report: George So...|     Breitbart|         Aaron Klein|2017-01-23|2017.0|  1.0|null|Billionaire Georg...|
# |10513|29249|Peter Schweizer: ...|     Breitbart|        John Hayward|2017-05-26|2017.0|  5.0|null|On Friday’s Breit...|
# |10608|29344|Mexican Border St...|     Breitbart|   Cartel Chronicles|2017-02-19|2017.0|  2.0|null|PIEDRAS NEGRAS, C...|
# |10646|29382|Maxine Waters: ’D...|     Breitbart|             Pam Key|2017-05-14|2017.0|  5.0|null|Saturday at a tow...|
# |  109|17410|Putin Led a Compl...|New York Times|Michael D. Shear ...|2017-01-07|2017.0|  1.0|null|WASHINGTON  —   P...|
# |11015|29751|White House: ’No ...|     Breitbart|          Edwin Mora|2017-01-25|2017.0|  1.0|null|White House press...|
# |11085|29821|Biggest Insurance...|     Breitbart|          Sean Moran|2017-03-10|2017.0|  3.0|null|Anthem, the natio...|
# |11268|30004|Miller: We Have P...|     Breitbart|             Pam Key|2017-02-12|2017.0|  2.0|null|Sunday on ABC’s “...|
# |11302|30038|Speaker Ryan’s Ob...|     Breitbart|          Sean Moran|2017-03-10|2017.0|  3.0|null|Speaker Ryan’s pl...|
# |11331|30067|Ann Coulter Tweet...|     Breitbart|         Lucas Nolan|2017-05-13|2017.0|  5.0|null|Conservative fire...|
# |11599|30335|Conway to Chuck T...|     Breitbart|             Pam Key|2017-01-22|2017.0|  1.0|null|Sunday on NBC’s “...|
# |11695|30431|WATCH: Vandals Tw...|     Breitbart|       Deborah Danan|2017-01-01|2017.0|  1.0|null|TEL AVIV  —   A J...|
# |11732|30468|Politico Magazine...|     Breitbart|         AWR Hawkins|2017-04-30|2017.0|  4.0|null|Although the NRA ...|
# |11766|30502|HHS Sec Price: Ex...|     Breitbart|           Jeff Poor|2017-05-12|2017.0|  5.0|null|Friday on Hugh He...|
# |11961|30697| Professional Act...|     Breitbart|         Aaron Klein|2017-01-18|2017.0|  1.0|null|While the protest...|
# |12115|30851|Putin: Syria Chem...|     Breitbart|        John Hayward|2017-04-11|2017.0|  4.0|null|At a Tuesday pres...|
# |12806|31542|Former Anthem-Pro...|     Breitbart|         Dylan Gwinn|2017-04-16|2017.0|  4.0|null|Players that prot...|
# |12830|31566|Teen Vogue Calls ...|     Breitbart|       Jerome Hudson|2017-06-12|2017.0|  6.0|null|  magazine Teen V...|
# +-----+-----+--------------------+--------------+--------------------+----------+------+-----+----+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Limpieza del DataFrame
# Creando un dataframe que contenga los contedidos de las publicaciones hechas y limpiando el contenido de caracteres especiales.

# %%
reg = '[^a-zA-Z ]'
reg1 = '[\s*]{1,}'
reg2 = '[\|’]'

# %%
full_df = full_df.withColumn("clean0", regexp_replace('Content', reg ,""))
full_df = full_df.withColumn("clean1", regexp_replace('clean0', reg1 ," "))
full_df = full_df.withColumn("clean2", regexp_replace('clean1', reg2, ""))
full_df = full_df.withColumn("ltrimmed_word",ltrim(col("clean2")))
full_df.select('Content', 'ltrimmed_word').show(440)
# Out:
# +--------------------+--------------------+
# |             Content|       ltrimmed_word|
# +--------------------+--------------------+
# |At the MARS 2017 ...|At the MARS tech ...|
# |”I remember who t...|I remember who th...|
# |Billionaire Georg...|Billionaire Georg...|
# |On Friday’s Breit...|On Fridays Breitb...|
# |PIEDRAS NEGRAS, C...|PIEDRAS NEGRAS Co...|
# |Saturday at a tow...|Saturday at a tow...|
# |WASHINGTON  —   P...|WASHINGTON Presid...|
# |White House press...|White House press...|
# |Anthem, the natio...|Anthem the nation...|
# |Sunday on ABC’s “...|Sunday on ABCs Th...|
# |Speaker Ryan’s pl...|Speaker Ryans pla...|
# |Conservative fire...|Conservative fire...|
# |Sunday on NBC’s “...|Sunday on NBCs Me...|
# |TEL AVIV  —   A J...|TEL AVIV A Jewish...|
# |Although the NRA ...|Although the NRA ...|
# |Friday on Hugh He...|Friday on Hugh He...|
# |While the protest...|While the protest...|
# |At a Tuesday pres...|At a Tuesday pres...|
# |Players that prot...|Players that prot...|
# |  magazine Teen V...|magazine Teen Vog...|
# |Good morning.  He...|Good morning Here...|
# |During his regula...|During his regula...|
# |Ernie Els, known ...|Ernie Els known a...|
# |OLATHE, Kan.  —  ...|OLATHE Kan The Ja...|
# |The chairman of t...|The chairman of t...|
# |An imam involved ...|An imam involved ...|
# |U. S. military of...|U S military offi...|
# |A group of techno...|A group of techno...|
# |Kid Rock’s name h...|Kid Rocks name ha...|
# |Senate Republican...|Senate Republican...|
# |Today is Earth Ho...|Today is Earth Ho...|
# |At the White Hous...|At the White Hous...|
# |Spring 1865. The ...|Spring The presid...|
# |In a recent inter...|In a recent inter...|
# |The Jerusalem Pos...|The Jerusalem Pos...|
# |PARIS (AP)  —   D...|PARIS AP Deepenin...|
# |Friday on ABC’s “...|Friday on ABCs Go...|
# |In March, Natalie...|In March Natalie ...|
# |Two cultures coll...|Two cultures coll...|
# |Breitbart Tech ed...|Breitbart Tech ed...|
# |The British media...|The British media...|
# |In her lengthy an...|In her lengthy an...|
# |Nine hundred and ...|Nine hundred and ...|
# |An armed citizen ...|An armed citizen ...|
# |Tom Coughlin resi...|Tom Coughlin resi...|
# |A group of vetera...|A group of vetera...|
# |On Tuesday’s broa...|On Tuesdays broad...|
# |ESPN for over a d...|ESPN for over a d...|
# |Arcade classic Ba...|Arcade classic Ba...|
# |One of the   stat...|One of the states...|
# |MONTERREY, Nuevo ...|MONTERREY Nuevo L...|
# |The NFL reported ...|The NFL reported ...|
# |Presidential cand...|Presidential cand...|
# |On the Monday edi...|On the Monday edi...|
# |A naked man enter...|A naked man enter...|
# |The Libertarian P...|The Libertarian P...|
# |With the New Year...|With the New Year...|
# |WASHINGTON  —   T...|WASHINGTON The Su...|
# |Each week, Nate C...|Each week Nate Co...|
# |Three police offi...|Three police offi...|
# |The Islamic State...|The Islamic State...|
# |A New Jersey moth...|A New Jersey moth...|
# |Washington (CNN) ...|Washington CNN Fo...|
# | (CNN) Donald Tru...|CNN Donald Trumps...|
# |Melbourne (CNN) H...|Melbourne CNN His...|
# | (CNN) Babies bor...|CNN Babies born i...|
# |JUBA, South Sudan...|JUBA South Sudan ...|
# |Washington (CNN) ...|Washington CNN Ne...|
# | (CNN) New York a...|CNN New York and ...|
# |Washington (CNN) ...|Washington CNN Pr...|
# |Washington (CNN) ...|Washington CNN Wh...|
# |Washington (CNN) ...|Washington CNN Pr...|
# | (CNN) President ...|CNN President Don...|
# | (CNN) Each year,...|CNN Each year env...|
# |Bridgewater Assoc...|Bridgewater Assoc...|
# |Erbil, Iraq (CNN)...|Erbil Iraq CNNI w...|
# | (CNN) Nine Malay...|CNN Nine Malaysia...|
# |Washington (CNN) ...|Washington CNN Th...|
# | (CNN) As public ...|CNN As public att...|
# |Washington (CNN) ...|Washington CNN Wh...|
# |Washington (CNN) ...|Washington CNN Pr...|
# |Here’s a look at ...|Heres a look at t...|
# | (CNN) Black Live...|CNN Black Lives M...|
# | (CNN) President ...|CNN President Don...|
# | (CNN) House Repu...|CNN House Republi...|
# | (CNN) On Saturda...|CNN On Saturday R...|
# |Washington (CNN) ...|Washington CNN Ne...|
# | (CNN) After a   ...|CNN After a week ...|
# |New York (CNN) Th...|New York CNN The ...|
# |London (CNN) At l...|London CNN At lea...|
# | (CNN) NASA’S Jet...|CNN NASAS Jet Pro...|
# | (CNN) South Kore...|CNN South Korea m...|
# | (CNN) Belgian au...|CNN Belgian autho...|
# |MIAMI  —   Amanda...|MIAMI Amanda Para...|
# | (CNN) A jaguar t...|CNN A jaguar that...|
# | (CNN) Donald Tru...|CNN Donald Trump ...|
# | (CNN) When the c...|CNN When the chie...|
# | (CNN) Whether st...|CNN Whether stunn...|
# | (CNN) Former Pen...|CNN Former Penn S...|
# |Last last week, B...|Last last week Bl...|
# |Donald Trump was ...|Donald Trump was ...|
# |On Thursday’s “O’...|On Thursdays ORei...|
# |Sunday on ABC’s “...|Sunday on ABCs Th...|
# |A priest in the t...|A priest in the t...|
# |Las Vegas  —   Sp...|Las Vegas Speakin...|
# |Janice Crouch, wh...|Janice Crouch who...|
# |(Associated Press...|Associated Press ...|
# |The creator of Je...|The creator of Je...|
# |CNN’s “The Lead” ...|CNNs The Lead hos...|
# |Bill Belichick ti...|Bill Belichick ti...|
# |While women are o...|While women are o...|
# |Wednesday on WABC...|Wednesday on WABC...|
# |Congressional leg...|Congressional leg...|
# |The battle betwee...|The battle betwee...|
# |From the BBC:[He ...|From the BBCHe to...|
# |A Mexican newspap...|A Mexican newspap...|
# |Twitter attempted...|Twitter attempted...|
# |A disabled Air Fo...|A disabled Air Fo...|
# |HOUSTON, Texas  —...|HOUSTON Texas A s...|
# |The mainstream me...|The mainstream me...|
# |Washington (CNN) ...|Washington CNN Se...|
# |Istanbul (CNN) La...|Istanbul CNN Lawm...|
# |Washington (CNN) ...|Washington CNN Ev...|
# | (CNN) White Hous...|CNN White House P...|
# | (CNN) An undocum...|CNN An undocument...|
# | (CNN) An innocen...|CNN An innocent m...|
# |Read in Chinese |...|Read in Chinese E...|
# |Washington (CNN) ...|Washington CNN Pr...|
# |Shanghai, China (...|Shanghai China CN...|
# |The Hague, Nether...|The Hague Netherl...|
# | (CNN) House Inte...|CNN House Intelli...|
# | (CNN) This was f...|CNN This was far ...|
# |Washington (CNN) ...|Washington CNN As...|
# |West Chester, Pen...|West Chester Penn...|
# | (CNN) Dallas res...|CNN Dallas reside...|
# | (CNN) NASA has n...|CNN NASA has new ...|
# | (CNN) Here’s som...|CNN Heres some ba...|
# | (CNN) Jurors rec...|CNN Jurors recomm...|
# | (CNN) Possible c...|CNN Possible coll...|
# | (CNN) A new drug...|CNN A new drug ca...|
# | (CNN) Some Repub...|CNN Some Republic...|
# | (CNN) In announc...|CNN In announcing...|
# |Statement for the...|Statement for the...|
# |Allendale, New Je...|Allendale New Jer...|
# +--------------------+--------------------+

# %% [markdown]
# ## Tokenización de los contenidos de las publicaciones
# Creacion de un dataframe con el contenido de la publicacion tokenizado

# %%
tokenization=Tokenizer(inputCol='ltrimmed_word',outputCol='tokens')

# %%
tokenized_df = tokenization.transform(full_df)

# %%
tokenized_df.select('Content', 'ltrimmed_word','tokens').show()
# Out:
# +--------------------+--------------------+--------------------+
# |             Content|       ltrimmed_word|              tokens|
# +--------------------+--------------------+--------------------+
# |At the MARS 2017 ...|At the MARS tech ...|[at, the, mars, t...|
# |”I remember who t...|I remember who th...|[i, remember, who...|
# |Billionaire Georg...|Billionaire Georg...|[billionaire, geo...|
# |On Friday’s Breit...|On Fridays Breitb...|[on, fridays, bre...|
# |PIEDRAS NEGRAS, C...|PIEDRAS NEGRAS Co...|[piedras, negras,...|
# |Saturday at a tow...|Saturday at a tow...|[saturday, at, a,...|
# |WASHINGTON  —   P...|WASHINGTON Presid...|[washington, pres...|
# |White House press...|White House press...|[white, house, pr...|
# |Anthem, the natio...|Anthem the nation...|[anthem, the, nat...|
# |Sunday on ABC’s “...|Sunday on ABCs Th...|[sunday, on, abcs...|
# |Speaker Ryan’s pl...|Speaker Ryans pla...|[speaker, ryans, ...|
# |Conservative fire...|Conservative fire...|[conservative, fi...|
# |Sunday on NBC’s “...|Sunday on NBCs Me...|[sunday, on, nbcs...|
# |TEL AVIV  —   A J...|TEL AVIV A Jewish...|[tel, aviv, a, je...|
# |Although the NRA ...|Although the NRA ...|[although, the, n...|
# |Friday on Hugh He...|Friday on Hugh He...|[friday, on, hugh...|
# |While the protest...|While the protest...|[while, the, prot...|
# |At a Tuesday pres...|At a Tuesday pres...|[at, a, tuesday, ...|
# |Players that prot...|Players that prot...|[players, that, p...|
# |  magazine Teen V...|magazine Teen Vog...|[magazine, teen, ...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Eliminar stopWords
# Eliminación de stopWord en la columna de contenido de las publicaciones, token tales como "I, and .or"

# %%
stopword_removal=StopWordsRemover(inputCol='tokens',outputCol='refined_tokens')

# %%
refined_df=stopword_removal.transform(tokenized_df)

# %%
refined_df.select('ltrimmed_word','tokens','refined_tokens').show()
# Out:
# +--------------------+--------------------+--------------------+
# |       ltrimmed_word|              tokens|      refined_tokens|
# +--------------------+--------------------+--------------------+
# |In Rayshell Byers...|[in, rayshell, by...|[rayshell, byers,...|
# |Sunday on CBSs Fa...|[sunday, on, cbss...|[sunday, cbss, fa...|
# |President Donald ...|[president, donal...|[president, donal...|
# |Sunday on CBSs Fa...|[sunday, on, cbss...|[sunday, cbss, fa...|
# |On the Thursday e...|[on, the, thursda...|[thursday, editio...|
# |A Never Trump mov...|[a, never, trump,...|[never, trump, mo...|
# |A man from Memphi...|[a, man, from, me...|[man, memphis, te...|
# |Do you know you a...|[do, you, know, y...|[know, going, die...|
# |Georgia lawmakers...|[georgia, lawmake...|[georgia, lawmake...|
# |Pres Trump on if ...|[pres, trump, on,...|[pres, trump, tap...|
# |According to a Po...|[according, to, a...|[according, polit...|
# |In a report this ...|[in, a, report, t...|[report, week, cn...|
# |The death of the ...|[the, death, of, ...|[death, american,...|
# |The mother of an ...|[the, mother, of,...|[mother, american...|
# |I was years old N...|[i, was, years, o...|[years, old, yet,...|
# |The Times of Isra...|[the, times, of, ...|[times, israel, r...|
# |In an exit memora...|[in, an, exit, me...|[exit, memorandum...|
# |The hot topic for...|[the, hot, topic,...|[hot, topic, spor...|
# |On Fridays broadc...|[on, fridays, bro...|[fridays, broadca...|
# |Barack Obama has ...|[barack, obama, h...|[barack, obama, b...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Vectorización del DataFrame

# %%
refined_df
# Out:
# DataFrame[_c0: string, id: string, title: string, publication: string, author: string, date: string, year: string, month: string, url: string, content: string, clean0: string, clean1: string, clean2: string, ltrimmed_word: string, tokens: array<string>, refined_tokens: array<string>]

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
from pyspark.sql.types import IntegerType

# %%
len_udf = udf(lambda s: len(s), IntegerType())
refined_df = refined_df.withColumn("token_count", len_udf(col('refined_tokens')))

# %%
refined_df.select('ltrimmed_word','tokens','refined_tokens','token_count').show()
# Out:
# +--------------------+--------------------+--------------------+-----------+
# |       ltrimmed_word|              tokens|      refined_tokens|token_count|
# +--------------------+--------------------+--------------------+-----------+
# |In Rayshell Byers...|[in, rayshell, by...|[rayshell, byers,...|        375|
# |Sunday on CBSs Fa...|[sunday, on, cbss...|[sunday, cbss, fa...|         96|
# |President Donald ...|[president, donal...|[president, donal...|         63|
# |Sunday on CBSs Fa...|[sunday, on, cbss...|[sunday, cbss, fa...|        101|
# |On the Thursday e...|[on, the, thursda...|[thursday, editio...|        128|
# |A Never Trump mov...|[a, never, trump,...|[never, trump, mo...|        714|
# |A man from Memphi...|[a, man, from, me...|[man, memphis, te...|        202|
# |Do you know you a...|[do, you, know, y...|[know, going, die...|        470|
# |Georgia lawmakers...|[georgia, lawmake...|[georgia, lawmake...|        156|
# |Pres Trump on if ...|[pres, trump, on,...|[pres, trump, tap...|        121|
# |According to a Po...|[according, to, a...|[according, polit...|        255|
# |In a report this ...|[in, a, report, t...|[report, week, cn...|        400|
# |The death of the ...|[the, death, of, ...|[death, american,...|        340|
# |The mother of an ...|[the, mother, of,...|[mother, american...|        318|
# |I was years old N...|[i, was, years, o...|[years, old, yet,...|        458|
# |The Times of Isra...|[the, times, of, ...|[times, israel, r...|         76|
# |In an exit memora...|[in, an, exit, me...|[exit, memorandum...|        400|
# |The hot topic for...|[the, hot, topic,...|[hot, topic, spor...|        257|
# |On Fridays broadc...|[on, fridays, bro...|[fridays, broadca...|         94|
# |Barack Obama has ...|[barack, obama, h...|[barack, obama, b...|        241|
# +--------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Agrupación de textos

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import CountVectorizer, HashingTF, IDF
from pyspark.ml.clustering import LDA, KMeans

# %%
aux_df = refined_df
aux_tf_idf = refined_df
aux_df = aux_df.drop('publication', 'author', 'publication', 'title', 'date', 'year', 'month', 'url', 'clean', 'clean0', 'clean1', 'clean2', 'tokens')
aux_df.show()
# Out:
# +-----+-----+--------------------+--------------------+--------------------+-----------+
# |  _c0|   id|             content|       ltrimmed_word|      refined_tokens|token_count|
# +-----+-----+--------------------+--------------------+--------------------+-----------+
# |10092|28828|At the MARS 2017 ...|At the MARS tech ...|[mars, tech, conf...|        233|
# |10101|28837|”I remember who t...|I remember who th...|[remember, people...|         61|
# |10236|28972|Billionaire Georg...|Billionaire Georg...|[billionaire, geo...|        392|
# |10513|29249|On Friday’s Breit...|On Fridays Breitb...|[fridays, breitba...|        551|
# |10608|29344|PIEDRAS NEGRAS, C...|PIEDRAS NEGRAS Co...|[piedras, negras,...|        192|
# |10646|29382|Saturday at a tow...|Saturday at a tow...|[saturday, town, ...|         51|
# |  109|17410|WASHINGTON  —   P...|WASHINGTON Presid...|[washington, pres...|        905|
# |11015|29751|White House press...|White House press...|[white, house, pr...|        175|
# |11085|29821|Anthem, the natio...|Anthem the nation...|[anthem, nations,...|        174|
# |11268|30004|Sunday on ABC’s “...|Sunday on ABCs Th...|[sunday, abcs, we...|        106|
# |11302|30038|Speaker Ryan’s pl...|Speaker Ryans pla...|[speaker, ryans, ...|        264|
# |11331|30067|Conservative fire...|Conservative fire...|[conservative, fi...|        186|
# |11599|30335|Sunday on NBC’s “...|Sunday on NBCs Me...|[sunday, nbcs, me...|        113|
# |11695|30431|TEL AVIV  —   A J...|TEL AVIV A Jewish...|[tel, aviv, jewis...|        207|
# |11732|30468|Although the NRA ...|Although the NRA ...|[although, nra, a...|        260|
# |11766|30502|Friday on Hugh He...|Friday on Hugh He...|[friday, hugh, he...|         91|
# |11961|30697|While the protest...|While the protest...|[protest, movemen...|        533|
# |12115|30851|At a Tuesday pres...|At a Tuesday pres...|[tuesday, press, ...|        254|
# |12806|31542|Players that prot...|Players that prot...|[players, protest...|        266|
# |12830|31566|  magazine Teen V...|magazine Teen Vog...|[magazine, teen, ...|        158|
# +-----+-----+--------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
fill = array().cast("array<string>")
tokens_a = when(col("refined_tokens").isNull(), fill).otherwise(col("refined_tokens"))
aux_df = aux_df.withColumn("refined_tokens", tokens_a)

# %%
cv = CountVectorizer(inputCol="refined_tokens", outputCol="rawFeatures")
cvmodel = cv.fit(aux_df)
featurizedData = cvmodel.transform(aux_df)
vocab = cvmodel.vocabulary
vocab
# Out:
# ['said',
#  'trump',
#  'people',
#  'one',
#  'new',
#  'president',
#  'also',
#  'us',
#  'like',
#  'mr',
#  'news',
#  'state',
#  'two',
#  'time',
#  'told',
#  'twitter',
#  'police',
#  'first',
#  'dont',
#  'states',
#  'going',
#  'years',
#  'think',
#  'last',
#  'clinton',
#  'house',
#  'campaign',
#  'donald',
#  'get',
#  'many',
#  'cnn',
#  'united',
#  'according',
#  'trumps',
#  'even',
#  'know',
#  'white',
#  'may',
#  'year',
#  'country',
#  'made',
#  'way',
#  'u',
#  'media',
#  'american',
#  'national',
#  'make',
#  'government',
#  'since',
#  'back',
#  'percent',
#  'officials',
#  'say',
#  'well',
#  'world',
#  'group',
#  'former',
#  'obama',
#  'july',
#  'security',
#  'see',
#  'including',
#  'want',
#  'breitbart',
#  'black',
#  'thats',
#  'report',
#  'im',
#  'says',
#  'much',
#  'still',
#  'week',
#  'called',
#  'times',
#  'law',
#  'support',
#  'day',
#  'three',
#  'statement',
#  'right',
#  'party',
#  'take',
#  'political',
#  'saying',
#  'follow',
#  'health',
#  'public',
#  'go',
#  'good',
#  'york',
#  'another',
#  'part',
#  'election',
#  'north',
#  'work',
#  'never',
#  'presidential',
#  'reported',
#  'man',
#  'washington',
#  'republican',
#  'hes',
#  'court',
#  'home',
#  'military',
#  'show',
#  'took',
#  'department',
#  'night',
#  'later',
#  'every',
#  'city',
#  'long',
#  'attack',
#  'around',
#  'hillary',
#  'office',
#  'intelligence',
#  'war',
#  'south',
#  'democratic',
#  'women',
#  'officers',
#  'family',
#  'really',
#  'use',
#  'help',
#  'asked',
#  'come',
#  'added',
#  'days',
#  'vote',
#  'fox',
#  'whether',
#  'isis',
#  'members',
#  'investigation',
#  'theres',
#  'need',
#  'friday',
#  'attacks',
#  'foreign',
#  'might',
#  'islamic',
#  'russian',
#  'went',
#  'wrote',
#  'thursday',
#  'top',
#  'look',
#  'great',
#  'administration',
#  'press',
#  'officer',
#  'bill',
#  'far',
#  'america',
#  'lives',
#  'update',
#  'killed',
#  'secretary',
#  'speech',
#  'wall',
#  'care',
#  'matter',
#  'et',
#  'put',
#  'pm',
#  'russia',
#  'little',
#  'left',
#  'used',
#  'reports',
#  'case',
#  'tuesday',
#  'ryan',
#  'committee',
#  'better',
#  'lot',
#  'best',
#  'video',
#  'americans',
#  'didnt',
#  'got',
#  'texas',
#  'read',
#  'business',
#  'doesnt',
#  'believe',
#  'point',
#  'information',
#  'something',
#  'place',
#  'community',
#  'children',
#  'change',
#  'came',
#  'monday',
#  'men',
#  'general',
#  'without',
#  'found',
#  'least',
#  'voters',
#  'international',
#  'power',
#  'university',
#  'month',
#  'yet',
#  'saturday',
#  'million',
#  'end',
#  'past',
#  'social',
#  'policy',
#  'next',
#  'authorities',
#  'leader',
#  'recent',
#  'morning',
#  'chief',
#  'second',
#  'number',
#  'john',
#  'among',
#  'evidence',
#  'several',
#  'official',
#  'big',
#  'however',
#  'known',
#  'things',
#  'cruz',
#  'deal',
#  'sunday',
#  'released',
#  'director',
#  'high',
#  'months',
#  'china',
#  'death',
#  'youre',
#  'pic',
#  'march',
#  'countries',
#  'decision',
#  'justice',
#  'become',
#  'interview',
#  'senate',
#  'theyre',
#  'four',
#  'issue',
#  'iraq',
#  'wednesday',
#  'post',
#  'seen',
#  'fact',
#  'major',
#  'companies',
#  'though',
#  'find',
#  'federal',
#  'call',
#  'life',
#  'groups',
#  'story',
#  'face',
#  'plan',
#  'rights',
#  'move',
#  'earlier',
#  'early',
#  'today',
#  'republicans',
#  'minister',
#  'outside',
#  'began',
#  'center',
#  'turkey',
#  'february',
#  'making',
#  'water',
#  'thought',
#  'tax',
#  'likely',
#  'https',
#  'system',
#  'issues',
#  'agency',
#  'working',
#  'program',
#  'senior',
#  'live',
#  'run',
#  'job',
#  'team',
#  'less',
#  'email',
#  'clintons',
#  'executive',
#  'company',
#  'real',
#  'james',
#  'possible',
#  'five',
#  'kind',
#  'fbi',
#  'able',
#  'immigration',
#  'online',
#  'getting',
#  'across',
#  'ago',
#  'give',
#  'cant',
#  'away',
#  'leaders',
#  'act',
#  'nations',
#  'posted',
#  'thing',
#  'list',
#  'question',
#  'open',
#  'always',
#  'shooting',
#  'article',
#  'clear',
#  'trying',
#  'college',
#  'fight',
#  'violence',
#  'gave',
#  'protest',
#  'taken',
#  'message',
#  'love',
#  'announced',
#  'problem',
#  'human',
#  'already',
#  'lead',
#  'often',
#  'head',
#  'baton',
#  'june',
#  'rouge',
#  'syria',
#  'shot',
#  'm',
#  'name',
#  'school',
#  'set',
#  'weeks',
#  'charges',
#  'win',
#  'local',
#  'actually',
#  'conference',
#  'order',
#  'leave',
#  'korea',
#  'mark',
#  'taking',
#  'response',
#  'gun',
#  'ever',
#  'keep',
#  'future',
#  'money',
#  'meeting',
#  'defense',
#  'won',
#  'ms',
#  'climate',
#  'action',
#  'course',
#  'movement',
#  'dr',
#  'force',
#  'victims',
#  'mean',
#  'anything',
#  'david',
#  'pay',
#  'muslim',
#  'described',
#  'someone',
#  'democrats',
#  'despite',
#  'held',
#  'questions',
#  'large',
#  'given',
#  'attorney',
#  'january',
#  'history',
#  'east',
#  'done',
#  'tell',
#  'means',
#  'close',
#  'following',
#  'along',
#  'staff',
#  'zika',
#  'happened',
#  'received',
#  'key',
#  'governor',
#  'let',
#  'border',
#  'board',
#  'county',
#  'jobs',
#  'member',
#  'led',
#  'role',
#  'peace',
#  'young',
#  'others',
#  'heard',
#  'enough',
#  'play',
#  'hours',
#  'florida',
#  'terrorist',
#  'com',
#  'facebook',
#  'coming',
#  'area',
#  'hate',
#  'risk',
#  'talk',
#  'saw',
#  'continue',
#  'full',
#  'together',
#  'vice',
#  'control',
#  'comes',
#  'suspect',
#  'medical',
#  'fighting',
#  'important',
#  'published',
#  'incident',
#  'congress',
#  'almost',
#  'data',
#  'shows',
#  'within',
#  'must',
#  'host',
#  'sanders',
#  'situation',
#  'students',
#  'candidate',
#  'different',
#  'person',
#  'prime',
#  'reporters',
#  'protect',
#  'whats',
#  'sure',
#  'started',
#  'arrested',
#  'stop',
#  'dead',
#  'sen',
#  'flynn',
#  'tv',
#  'johnson',
#  'paul',
#  'europe',
#  'understand',
#  'convention',
#  'employees',
#  'wrong',
#  'body',
#  'enforcement',
#  'nothing',
#  'watch',
#  'hope',
#  'heres',
#  'process',
#  'involved',
#  'website',
#  'billion',
#  'tweet',
#  'effort',
#  'nation',
#  'running',
#  'research',
#  'nearly',
#  'free',
#  'short',
#  'hit',
#  'al',
#  'families',
#  'service',
#  'street',
#  'calls',
#  'although',
#  'behind',
#  'study',
#  'chairman',
#  'hard',
#  'residents',
#  'turned',
#  'expected',
#  'side',
#  'looking',
#  'continued',
#  'line',
#  'crisis',
#  'j',
#  'series',
#  'mexico',
#  'council',
#  'car',
#  'crime',
#  'mother',
#  'individuals',
#  'whose',
#  'food',
#  'george',
#  'nominee',
#  'air',
#  'putin',
#  'happen',
#  'noted',
#  'claims',
#  'event',
#  'november',
#  'global',
#  'victory',
#  'everything',
#  'using',
#  'lost',
#  'middle',
#  'michael',
#  'recently',
#  'comments',
#  'related',
#  'position',
#  'focus',
#  'fire',
#  'moment',
#  'ive',
#  'special',
#  'scene',
#  'threat',
#  'try',
#  'wants',
#  'workers',
#  'legal',
#  'april',
#  'talking',
#  'presidents',
#  'reportedly',
#  'reason',
#  'terrorism',
#  'muslims',
#  'conservative',
#  'emails',
#  'carolina',
#  'daily',
#  'organization',
#  'near',
#  'happening',
#  'actions',
#  'felt',
#  'society',
#  'experience',
#  'armed',
#  'hand',
#  'appeared',
#  'provide',
#  'idea',
#  'wanted',
#  'parents',
#  'islam',
#  'european',
#  'camp',
#  'forces',
#  'areas',
#  'age',
#  'old',
#  'comment',
#  'spent',
#  'makes',
#  'release',
#  'accused',
#  'small',
#  'supreme',
#  'building',
#  'personal',
#  'instead',
#  'obamas',
#  'attention',
#  'words',
#  'star',
#  'sexual',
#  'economic',
#  'worked',
#  'became',
#  'mexican',
#  'bush',
#  'wasnt',
#  'quickly',
#  'lee',
#  'speaking',
#  'california',
#  'radio',
#  'target',
#  'claim',
#  'stand',
#  'hospital',
#  'third',
#  'six',
#  'leading',
#  'terror',
#  'calling',
#  'student',
#  'migrants',
#  'isnt',
#  'example',
#  'spokesman',
#  'tried',
#  'price',
#  'freedom',
#  'true',
#  'supporters',
#  'debate',
#  'current',
#  'start',
#  'inside',
#  'wont',
#  'immediately',
#  'address',
#  'strong',
#  'late',
#  'chinese',
#  'citizens',
#  'create',
#  'barack',
#  'toward',
#  'civil',
#  'spoke',
#  'services',
#  'failed',
#  'woman',
#  'gov',
#  'yes',
#  'book',
#  'kushner',
#  'cause',
#  'mayor',
#  'french',
#  'safe',
#  'music',
#  'responded',
#  'army',
#  'allegations',
#  'record',
#  'hands',
#  'friends',
#  'wafb',
#  'sent',
#  'thousands',
#  'based',
#  'protests',
#  'everyone',
#  'reporter',
#  'turkish',
#  'race',
#  'politics',
#  'son',
#  'majority',
#  'letter',
#  'cities',
#  'declared',
#  'duffy',
#  'fighters',
#  'airport',
#  'latest',
#  'union',
#  'adviser',
#  'afghanistan',
#  'british',
#  'interest',
#  'land',
#  'answer',
#  'forward',
#  'identified',
#  'met',
#  'primary',
#  'criminal',
#  'wife',
#  'relations',
#  'carry',
#  'fired',
#  'rather',
#  'boston',
#  'iran',
#  'san',
#  'probably',
#  'miami',
#  'hearing',
#  'murder',
#  'perhaps',
#  'korean',
#  'paris',
#  'living',
#  'brought',
#  'warned',
#  'la',
#  'september',
#  'child',
#  'bad',
#  'leaving',
#  'efforts',
#  'storm',
#  'concerned',
#  'helped',
#  'brain',
#  'feel',
#  'hold',
#  'millions',
#  'cuomo',
#  'obamacare',
#  'financial',
#  'room',
#  'gop',
#  'decided',
#  'revealed',
#  'game',
#  'saudi',
#  'multiple',
#  'bernie',
#  'claimed',
#  'west',
#  'previously',
#  'trust',
#  'p',
#  'throughout',
#  'believed',
#  'standing',
#  'points',
#  'votes',
#  'criticism',
#  'parties',
#  'audience',
#  'politicians',
#  'weekend',
#  'guy',
#  'killing',
#  'documents',
#  'seems',
#  'los',
#  'weapons',
#  'speak',
#  'review',
#  'refugees',
#  'ceo',
#  'eastern',
#  'especially',
#  'die',
#  'bring',
#  'scalia',
#  'sense',
#  'judge',
#  'film',
#  'simply',
#  'goes',
#  'sex',
#  'reach',
#  'raised',
#  'drug',
#  'adding',
#  'note',
#  'cartel',
#  'december',
#  'pretty',
#  'senator',
#  'october',
#  'prison',
#  'technology',
#  'remarks',
#  'numbers',
#  'plans',
#  'confirmed',
#  'results',
#  'hurricane',
#  'serious',
#  'opportunity',
#  'charged',
#  'mind',
#  'syrian',
#  'showed',
#  'front',
#  'beach',
#  'relationship',
#  'records',
#  'laws',
#  'lawsuit',
#  'channel',
#  'played',
#  'allies',
#  'illegal',
#  'popular',
#  'overall',
#  'visit',
#  'terrorists',
#  'courts',
#  'speaker',
#  'fall',
#  'governments',
#  'telling',
#  'missile',
#  'rise',
#  'hill',
#  'somebody',
#  'beyond',
#  'tech',
#  'flint',
#  'impact',
#  'effect',
#  'level',
#  'individual',
#  'difficult',
#  'stay',
#  'democrat',
#  'maybe',
#  'soon',
#  'nomination',
#  'countrys',
#  'lets',
#  'green',
#  'fans',
#  'private',
#  'carried',
#  'communities',
#  'include',
#  'de',
#  'repeatedly',
#  'per',
#  'allow',
#  'economy',
#  'central',
#  'th',
#  'created',
#  'c',
#  'foundation',
#  'explained',
#  'anyone',
#  'voice',
#  'responsibility',
#  'trial',
#  'spicer',
#  'various',
#  'project',
#  'tonight',
#  'whole',
#  'common',
#  'longer',
#  'addition',
#  'playing',
#  'performance',
#  'games',
#  'shes',
#  'step',
#  'ted',
#  'died',
#  'ask',
#  'august',
#  'kill',
#  'else',
#  'provided',
#  'sports',
#  'eight',
#  'ones',
#  'fear',
#  'award',
#  'st',
#  'establishment',
#  'presidency',
#  'language',
#  'cut',
#  'looked',
#  'anthem',
#  'environmental',
#  'due',
#  'conversation',
#  'original',
#  'w',
#  'lawyer',
#  'word',
#  'concerns',
#  'violent',
#  'britain',
#  'share',
#  'rules',
#  'insurance',
#  'box',
#  'charlie',
#  'access',
#  'potential',
#  'similar',
#  'network',
#  'success',
#  'collusion',
#  'pass',
#  'jersey',
#  'diabetes',
#  'operation',
#  'rally',
#  'conditions',
#  'weve',
#  'view',
#  'result',
#  'source',
#  'critics',
#  'lawmakers',
#  'events',
#  'significant',
#  'half',
#  'elected',
#  'americas',
#  'prepared',
#  'firm',
#  'robert',
#  'needed',
#  'ban',
#  'strategy',
#  'return',
#  'capital',
#  'wouldnt',
#  'seven',
#  'organizations',
#  'cases',
#  'tweeted',
#  'leadership',
#  'author',
#  'briefing',
#  'meetings',
#  'choice',
#  'mission',
#  'seem',
#  'analyst',
#  'cost',
#  'reached',
#  'budget',
#  'remains',
#  'treatment',
#  'wounded',
#  'argued',
#  'associated',
#  'looks',
#  'nobody',
#  'products',
#  'ability',
#  'referring',
#  'honor',
#  'poor',
#  'victim',
#  'chris',
#  'stated',
#  'trade',
#  'main',
#  'resources',
#  'finally',
#  'single',
#  'culture',
#  'consider',
#  'park',
#  'enemy',
#  'battle',
#  'sea',
#  'included',
#  'professor',
#  'god',
#  'photos',
#  'legislation',
#  'store',
#  'homes',
#  'entire',
#  'activists',
#  'direct',
#  'hasnt',
#  'father',
#  'higher',
#  'internet',
#  'ruling',
#  'crowd',
#  'field',
#  'club',
#  'jason',
#  ...]

# %%
hashingTF = HashingTF(inputCol="refined_tokens", outputCol="rawFeatures")
tf_df = hashingTF.transform(aux_tf_idf)
tf_df.select(['refined_tokens', 'rawFeatures']).show()
# Out:
# +--------------------+--------------------+
# |      refined_tokens|         rawFeatures|
# +--------------------+--------------------+
# |[mars, tech, conf...|(262144,[4054,487...|
# |[remember, people...|(262144,[408,6051...|
# |[billionaire, geo...|(262144,[1973,232...|
# |[fridays, breitba...|(262144,[14,619,6...|
# |[piedras, negras,...|(262144,[2281,271...|
# |[saturday, town, ...|(262144,[7612,102...|
# |[washington, pres...|(262144,[619,646,...|
# |[white, house, pr...|(262144,[7612,102...|
# |[anthem, nations,...|(262144,[2801,606...|
# |[sunday, abcs, we...|(262144,[1667,410...|
# |[speaker, ryans, ...|(262144,[4871,991...|
# |[conservative, fi...|(262144,[3834,910...|
# |[sunday, nbcs, me...|(262144,[6781,761...|
# |[tel, aviv, jewis...|(262144,[1076,197...|
# |[although, nra, a...|(262144,[622,4200...|
# |[friday, hugh, he...|(262144,[4349,579...|
# |[protest, movemen...|(262144,[535,1461...|
# |[tuesday, press, ...|(262144,[1882,273...|
# |[players, protest...|(262144,[619,4037...|
# |[magazine, teen, ...|(262144,[2731,508...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
idf = IDF(inputCol="rawFeatures", outputCol="features", minDocFreq=5)
ft_idf = idf.fit(tf_df).transform(tf_df)
ft_idf.select(['refined_tokens', 'features']).show()
# Out:
# +--------------------+--------------------+
# |      refined_tokens|            features|
# +--------------------+--------------------+
# |[mars, tech, conf...|(262144,[4054,487...|
# |[remember, people...|(262144,[408,6051...|
# |[billionaire, geo...|(262144,[1973,232...|
# |[fridays, breitba...|(262144,[14,619,6...|
# |[piedras, negras,...|(262144,[2281,271...|
# |[saturday, town, ...|(262144,[7612,102...|
# |[washington, pres...|(262144,[619,646,...|
# |[white, house, pr...|(262144,[7612,102...|
# |[anthem, nations,...|(262144,[2801,606...|
# |[sunday, abcs, we...|(262144,[1667,410...|
# |[speaker, ryans, ...|(262144,[4871,991...|
# |[conservative, fi...|(262144,[3834,910...|
# |[sunday, nbcs, me...|(262144,[6781,761...|
# |[tel, aviv, jewis...|(262144,[1076,197...|
# |[although, nra, a...|(262144,[622,4200...|
# |[friday, hugh, he...|(262144,[4349,579...|
# |[protest, movemen...|(262144,[535,1461...|
# |[tuesday, press, ...|(262144,[1882,273...|
# |[players, protest...|(262144,[619,4037...|
# |[magazine, teen, ...|(262144,[2731,508...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
kmeans = KMeans(k=25)
kmeans_model = kmeans.fit(ft_idf).transform(ft_idf)
kmeans_model.select('refined_tokens', 'features', 'prediction').show()
# Out:
# +--------------------+--------------------+----------+
# |      refined_tokens|            features|prediction|
# +--------------------+--------------------+----------+
# |[rayshell, byers,...|(262144,[619,813,...|        13|
# |[sunday, cbss, fa...|(262144,[3924,678...|        13|
# |[president, donal...|(262144,[5381,576...|        13|
# |[sunday, cbss, fa...|(262144,[6369,761...|        13|
# |[thursday, editio...|(262144,[4954,761...|        13|
# |[never, trump, mo...|(262144,[14,619,1...|        13|
# |[man, memphis, te...|(262144,[619,1727...|        13|
# |[know, going, die...|(262144,[1727,184...|        13|
# |[georgia, lawmake...|(262144,[513,2548...|        13|
# |[pres, trump, tap...|(262144,[6781,761...|        13|
# |[according, polit...|(262144,[440,4872...|        13|
# |[report, week, cn...|(262144,[1846,232...|        13|
# |[death, american,...|(262144,[1846,243...|        13|
# |[mother, american...|(262144,[836,994,...|        13|
# |[years, old, yet,...|(262144,[571,991,...|        13|
# |[times, israel, r...|(262144,[8053,113...|        13|
# |[exit, memorandum...|(262144,[632,1769...|        13|
# |[hot, topic, spor...|(262144,[3326,410...|        13|
# |[fridays, broadca...|(262144,[1156,232...|        13|
# |[barack, obama, b...|(262144,[329,646,...|        13|
# +--------------------+--------------------+----------+
# only showing top 20 rows

# %%
lda = LDA(k=25, seed=100, optimizer="em", featuresCol="features")
lda_model = lda.fit(kmeans_model).transform(kmeans_model)
lda_model.select('refined_tokens', 'features', 'prediction', 'topicDistribution').show()
# Out:
# +--------------------+--------------------+----------+--------------------+
# |      refined_tokens|            features|prediction|   topicDistribution|
# +--------------------+--------------------+----------+--------------------+
# |[rayshell, byers,...|(262144,[619,813,...|        13|[0.00394299711127...|
# |[sunday, cbss, fa...|(262144,[3924,678...|        13|[0.01087772223647...|
# |[president, donal...|(262144,[5381,576...|        13|[0.01548647714208...|
# |[sunday, cbss, fa...|(262144,[6369,761...|        13|[0.01070375926400...|
# |[thursday, editio...|(262144,[4954,761...|        13|[0.00858246161785...|
# |[never, trump, mo...|(262144,[14,619,1...|        13|[0.00201197972260...|
# |[man, memphis, te...|(262144,[619,1727...|        13|[0.00605981755409...|
# |[know, going, die...|(262144,[1727,184...|        13|[0.00307656632882...|
# |[georgia, lawmake...|(262144,[513,2548...|        13|[0.00669172619761...|
# |[pres, trump, tap...|(262144,[6781,761...|        13|[0.00906105075052...|
# |[according, polit...|(262144,[440,4872...|        13|[0.00741481347576...|
# |[report, week, cn...|(262144,[1846,232...|        13|[0.00377771893691...|
# |[death, american,...|(262144,[1846,243...|        13|[0.00605586647477...|
# |[mother, american...|(262144,[836,994,...|        13|[0.00437653866748...|
# |[years, old, yet,...|(262144,[571,991,...|        13|[0.00321993413202...|
# |[times, israel, r...|(262144,[8053,113...|        13|[0.01374836228879...|
# |[exit, memorandum...|(262144,[632,1769...|        13|[0.00339696705658...|
# |[hot, topic, spor...|(262144,[3326,410...|        13|[0.01273946163043...|
# |[fridays, broadca...|(262144,[1156,232...|        13|[0.01168733723600...|
# |[barack, obama, b...|(262144,[329,646,...|        13|[0.00572602470979...|
# +--------------------+--------------------+----------+--------------------+
# only showing top 20 rows

# %%
lda_model.groupBy('prediction').count().show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |        13|  377|
# |        21|    1|
# |         0|    3|
# |        15|    3|
# |         3|    1|
# |        14|    1|
# |        11|    2|
# |        12|    2|
# |         4|    1|
# |        16|    1|
# |         2|    1|
# |        17|    1|
# |        10|    1|
# |        23|    1|
# |        22|    1|
# |         1|    1|
# |        19|    1|
# |        18|    1|
# +----------+-----+
